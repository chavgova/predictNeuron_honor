# %% [markdown]
# Imports

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import glob
import scipy.io
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, GRU
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
from tensorflow.keras.models import Sequential, model_from_json

# %% [markdown]
# Load Data

# %%
label_data_folder = "/content/drive/MyDrive/Single channels data/Marked spike vectors"
raw_data_folder = "/content/drive/MyDrive/Single channels data/28102021_03_01_nbasal_0001/data"

# %%
os.chdir(raw_data_folder)
mat_files = glob.glob("*.mat")

data_dict = {}

for file in mat_files[:20]:
    # Load the .mat file using scipy.io.loadmat
    mat = scipy.io.loadmat(file)
    data_dict[file[27:30]] = np.concatenate(mat['data'])

print(data_dict.keys())
raw_df = pd.DataFrame.from_dict(data_dict, orient='columns')
raw_df
# Out:
# dict_keys(['A02', 'A05', 'A03', 'B07', 'B06', 'B01', 'B03', 'A06', 'B02', 'B05', 'C06', 'C03', 'C02', 'C05', 'C04', 'C01', 'D01', 'C07', 'D03', 'D02'])
#               A02       A05       A03       B07       B06       B01       B03  \
# 0       -1.921908 -4.485947  2.472312 -1.004966  2.960513  1.983918  1.373807
# 1       -1.250521 -6.561143  1.007469 -3.202231  0.824282  3.326691  1.495877
# 2        0.397428 -4.546983  2.167137 -1.981528 -1.311948  3.814972  1.312772
# 3       -4.546420 -3.936631  4.242332 -4.911216 -0.884702  4.364289 -2.166232
# 4       -2.715365 -7.415635  4.181297 -2.103599  3.815005  1.068390  3.449002
# ...           ...       ...       ...       ...       ...       ...       ...
# 2998995  0.153287 -1.006944 -2.532570 -0.821860  3.021548  3.143586  0.641385
# 2998996  0.763639 -2.166612 -3.326027  5.281655  3.143618  1.922882  3.937284
# 2998997  1.801236 -1.067979 -0.640481  0.765054  2.716372 -1.800262 -2.288302
# 2998998  5.097135 -9.979112  0.580223  0.398843 -0.884702  0.763215 -2.776583
# 2998999  3.632291 -2.227647  1.129539  0.093667  0.641177 -0.884735  0.580350
#
#                A06       B02       B05       C06       C03       C02  \
# 0        -2.959032  0.274880 -0.762878  0.031140  3.020819  5.462379
# 1         0.886183 -0.030296  1.190247  0.580456  2.959784  4.119606
# 2         0.519972 -1.861351  1.922668  1.251843  0.335272  1.617165
# 3         1.557570 -1.983421  0.274719 -0.701282 -3.448907  0.457497
# 4        -0.334520  0.702126  4.791321 -0.884388  2.532538 -1.190453
# ...            ...       ...       ...       ...       ...       ...
# 2998995 -10.893602  1.983864  1.190247 -3.203724 -2.777521 -4.486351
# 2998996 -13.579149  4.547340 -2.349793 -2.410267 -3.387872  1.434059
# 2998997  -5.888719 -2.227562 -3.021179 -5.095814 -3.815118 -0.763207
# 2998998   2.534132 -0.701683 -2.471863 -5.645130 -0.763361 -1.068382
# 2998999   1.435499  1.251442  3.082336 -2.654407 -1.007501 -3.021507
#
#               C05       C04       C01       D01       C07       D03       D02
# 0       -2.471503 -1.556942  0.885219 -0.762241 -1.067851  0.336652 -5.341440
# 1       -2.898749 -0.641415 -1.312047 -3.569858 -0.152323  2.106672 -4.609018
# 2        2.167169 -1.556942 -3.875523 -0.823276 -5.889628 -0.212664 -2.716929
# 3        1.190607  2.532413 -4.852086 -8.208530  1.922872  0.214582  1.921743
# 4        0.397150 -0.641415  1.800746  0.397427  0.458028 -0.212664 -1.130015
# ...           ...       ...       ...       ...       ...       ...       ...
# 2998995 -7.110175  2.715519  4.059047  0.397427  5.218770 -0.639910  1.799673
# 2998996 -5.645331  0.029972  2.838344 -4.058139  5.829122  2.717023  3.020376
# 2998997 -8.513983 -0.519344 -1.556187 -2.837436  2.716329 -5.034441  1.311392
# 2998998 -9.673651 -6.867001 -3.997594  0.214322  7.171895 -1.189227 -2.533823
# 2998999 -5.096014 -2.594540 -0.884801 -2.166050  5.096700 -1.067156  1.433462
#
# [2999000 rows x 20 columns]

# %% [markdown]
# Absolute values of the raw data

# %%
#raw_df = raw_df.abs()

# %% [markdown]
# *   0 - no spike
# *   1 - spike

# %% [markdown]
# example data

# %%
plt.figure(figsize=(25,7))
plt.plot(raw_df['A06'], linewidth = 1)
plt.show()

# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# variables

# %%
neurons = ['A06'] # neurons data

n_data_points = 2 # number of data points considered for training # V n=2, 1<t<10
t_data_points = 3 # number of FUTURE data points in which is predicted if there is a spike or no

# %%
raw_df = raw_df[neurons]

raw_data = raw_df.values.T

raw_data.shape
# Out:
# (1, 2999000)

# %% [markdown]
# Scaling

# %%
raw_data = raw_data[0][:-1]

# %%
raw_data.shape[0]// n_data_points
# Out:
# 1499499

# %% [markdown]
# Split RAW data; Input-Output

# %%
smaller_parts = []
samp = []

labels = []

num_parts = raw_data.shape[0] // n_data_points
for i in range(0, num_parts-1):
    raw_part = raw_data[i * n_data_points: (i + 1) * n_data_points]
    smaller_parts.append(raw_part)
    future = raw_data[(i + 1) * n_data_points : ((i + 1) * n_data_points + t_data_points)]
    labels.append(future)

labels = labels[:-1]
smaller_parts = smaller_parts[:-1]
# Convert the list of smaller parts to a NumPy array
raw_split_data = np.array(smaller_parts)
labels = np.array(labels)

raw_split_data.shape, labels.shape
# Out:
# ((1499497, 2), (1499497, 3))

# %%
raw_split_data = np.reshape(raw_split_data, (raw_split_data.shape[0], 1, raw_split_data.shape[1]))

# %% [markdown]
# # Test-Train split
# wirth the same ratio of 0s and 1s in test and train data

# %%
X_train, X_test, y_train, y_test = train_test_split(raw_split_data, labels, test_size=0.2, shuffle=False)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (1199597, 1, 2)
# X_test shape: (299900, 1, 2)
# y_train shape: (1199597, 3)
# y_test shape: (299900, 3)

# %%
y_test[143]
# Out:
# array([ 1.0692885 , -5.40043807, -0.76176619])

# %% [markdown]
# # Model

# %%
model = Sequential()
model.add(GRU(n_data_points, input_shape=(1, n_data_points), return_sequences=True))  # Input layer
model.add(GRU(units=32, return_sequences=True))
model.add(GRU(units=16, return_sequences=False))
model.add(Dense(8, activation='tanh'))
model.add(Dense(t_data_points, activation='linear'))  # Output layer with 5 neurons and linear activation (binary classification)

# Specify class weights
class_weights = {0: 1, 1: 200}

model.compile(optimizer='adam', loss='mse')

# %%
tf.keras.utils.plot_model(
    model,
    to_file="img_model.png",
    show_shapes=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
)

tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# class_weight=class_weights,

# %%
history_model = model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 37488/37488 [==============================] - 229s 6ms/step - loss: 13.3610 - val_loss: 14.1984
# Epoch 2/10
# 37488/37488 [==============================] - 216s 6ms/step - loss: 12.9017 - val_loss: 14.1527
# Epoch 3/10
# 37488/37488 [==============================] - 225s 6ms/step - loss: 12.8331 - val_loss: 14.0135
# Epoch 4/10
# 37488/37488 [==============================] - 207s 6ms/step - loss: 12.8032 - val_loss: 14.0894
# Epoch 5/10
# 37488/37488 [==============================] - 207s 6ms/step - loss: 12.7898 - val_loss: 14.0931
# Epoch 6/10
# 37488/37488 [==============================] - 206s 5ms/step - loss: 12.7828 - val_loss: 14.2435
# Epoch 7/10
# 37488/37488 [==============================] - 208s 6ms/step - loss: 12.7625 - val_loss: 14.0342
# Epoch 8/10
# 37488/37488 [==============================] - 207s 6ms/step - loss: 12.7527 - val_loss: 14.0500
# Epoch 9/10
# 37488/37488 [==============================] - 211s 6ms/step - loss: 12.7472 - val_loss: 14.0884
# Epoch 10/10
# 37488/37488 [==============================] - 256s 7ms/step - loss: 12.7433 - val_loss: 14.2677

# %%
# serialize model to JSON
model_json = model.to_json()
with open("/content/drive/MyDrive/models/model_GRU_notnorm_2_3_noShuff_A06.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("/content/drive/MyDrive/models/model_GRU_notnorm_2_3_noShuff_A06.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
plt.figure(figsize=(10,6))
plt.plot(history_model.history['loss'], 'm', linewidth=3)
plt.plot(history_model.history['val_loss'], 'b', linewidth=3)
plt.legend(['loss', 'val_loss'], fontsize=13)
plt.xlabel('epochs')
plt.ylabel('loss', fontsize=12)
plt.grid(True)
plt.show()

# %%
# Load the model architecture from the JSON file
with open("/content/drive/MyDrive/models/model_GRU_notnorm_2_3_noShuff_A06.json", "r") as json_file:
    loaded_model_json = json_file.read()

loaded_model = model_from_json(loaded_model_json)

# Load the model weights from the HDF5 file
loaded_model.load_weights("/content/drive/MyDrive/models/model_GRU_notnorm_2_3_noShuff_A06.h5")

print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
pred = loaded_model.predict(X_test)
# Out:
# 9372/9372 [==============================] - 33s 3ms/step

# %%
pred.shape
# Out:
# (299900, 3)

# %%
pred
# Out:
# array([[ 1.2372417 ,  0.96507645,  0.79051995],
#        [-0.09594774, -0.05483937, -0.03083277],
#        [ 0.3862822 ,  0.31474853,  0.267285  ],
#        ...,
#        [ 1.6746743 ,  1.2988551 ,  1.0588636 ],
#        [-7.980625  , -6.087297  , -4.811348  ],
#        [-3.8173742 , -2.9152446 , -2.3275862 ]], dtype=float32)

# %%
pred.shape
# Out:
# (299900, 3)

# %%
mae = mean_absolute_error(y_test, pred)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 2.512697431003541

# %%
sample = 2

plt.figure(figsize=(10,5))
plt.hlines(y=0, color='black', xmin=0, xmax=2, linestyles='dotted')
plt.plot(y_test[sample], linewidth = 1, color='b')
plt.plot(pred[sample], linewidth = 1, color='r')
plt.ylim(-50, 50)
plt.legend(["0", "real", "predicted"], loc="lower right")
plt.title('Noise prediction')
plt.show()

# %%
sample = 8845

plt.figure(figsize=(10,5))
plt.hlines(y=0, color='black', xmin=0, xmax=2, linestyles='dotted')
plt.plot(y_test[sample], linewidth = 1, color='b')
plt.plot(pred[sample], linewidth = 1, color='r')
plt.ylim(-50, 50)
plt.legend(["0", "real", "predicted"], loc="lower right")
plt.title('Positive Spike Prediction')
plt.show()

# %%
sample = 8145

plt.figure(figsize=(10,5))
plt.hlines(y=0, color='black', xmin=0, xmax=2, linestyles='dotted')
plt.plot(y_test[sample], linewidth = 1, color='b')
plt.plot(pred[sample], linewidth = 1, color='r')
plt.ylim(-50, 50)
plt.legend(["0", "real", "predicted"], loc="lower right")
plt.title('Negative Spike Prediction')
plt.show()

# %%
for a in range(0, 10000):
  if max(y_test[a]) < -20:
    print(a, '- - ', y_test[a])
# Out:
# 8120 - -  [-31.95073103 -27.80034041 -23.10063338]
# 8123 - -  [-32.62211775 -30.11967635 -22.18510603]
# 8126 - -  [-45.37846541 -30.6079576  -23.16166853]
# 8143 - -  [-29.08207869 -40.00737166 -32.01176619]
# 8144 - -  [-32.01176619 -25.96928572 -26.2744615 ]
# 8145 - -  [-26.2744615  -40.80082869 -38.11528182]
# 8152 - -  [-41.10600447 -35.4907701  -28.16655135]
# 8183 - -  [-31.82866072 -26.15239119 -22.12407088]
# 8203 - -  [-23.22270369 -29.14311385 -20.59819197]
# 8213 - -  [-46.17192244 -79.25297713 -73.63774275]
# 8214 - -  [-73.63774275 -50.32231307 -39.82426619]
# 8215 - -  [-39.82426619 -42.93705916 -37.74907088]
# 8234 - -  [-26.88481307 -24.07719588 -20.10991072]
# 8383 - -  [-28.71586775 -27.06791853 -21.57475447]
# 8723 - -  [-73.08842635 -61.12553572 -42.75395369]
# 8743 - -  [-48.79643416 -40.61772322 -21.20854353]
# 8758 - -  [-20.78129744 -24.01616072 -24.56547713]
# 8783 - -  [-44.58500838 -41.16703963 -25.05375838]
# 8857 - -  [-21.63578963 -29.50932478 -20.72026228]
